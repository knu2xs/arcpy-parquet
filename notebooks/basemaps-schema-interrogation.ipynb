# %%
# Basemaps Schema Interrogation

# %%
import pandas as pd

# %%
schema_pth = r"D:\projects\ba-data-engineering\data\reference\fsq_basemaps_schema.csv"

# %%
schema_df = pd.read_csv(schema_pth)

schema_df
# Out:
#             field_name field_type  field_precision  field_scale  field_length  \
# 0      fsq_category_id     String                0            0            10
# 1   fsq_category_label     String                0            0           500
# 2                Carto    Integer                0            0             4
# 3    SelectionPriority    Integer                0            0             4
# 4          LABEL_LOCAL     String                0            0           200
# ..                 ...        ...              ...          ...           ...
# 81             twitter     String                0            0            50
# 82         description     String                0            0           200
# 83              rating    Integer                0            0             4
# 84               price     String                0            0            20
# 85          popularity     Double                0            0             8
#
# ...

# %%
schema_dict = {k: v for k, v in zip(schema_df['field_name'], schema_df.to_dict('records'))}

schema_dict
# Out:
# {'fsq_category_id': {'field_name': 'fsq_category_id',
#   'field_type': 'String',
#   'field_precision': 0,
#   'field_scale': 0,
#   'field_length': 10,
#   'field_alias': 'fsq_category_id',
#   'field_is_nullable': True,
#   'field_is_required': False,
#   'field_domain': nan},
#  'fsq_category_label': {'field_name': 'fsq_category_label',
#   'field_type': 'String',
#   'field_precision': 0,
#   'field_scale': 0,
#   'field_length': 500,
#   'field_alias': 'fsq_category_label',
#   'field_is_nullable': True,
#   'field_is_required': False,
#   'field_domain': nan},
#  'Carto': {'field_name': 'Carto',
#   'field_type': 'Integer',
#   'field_precision': 0,
#   'field_scale': 0,
#   'field_length': 4,
#   'field_alias': 'Carto',
#   'field_is_nullable': True,
#   'field_is_required': False,
#   'field_domain': nan},
#  'SelectionPriority': {'field_name': 'SelectionPriority',
#   'field_type': 'Integer',
#   'field_precision': 0,
#   'field_scale': 0,
#   'field_length': 4,
# ...
